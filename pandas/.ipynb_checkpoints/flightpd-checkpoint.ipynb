# %%
import pandas as pd

# %%
df=pd.read_csv("data/movie_metadata.csv")
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df['duration'].head(10)
# Out:
# 0    178.0
# 1    169.0
# 2    148.0
# 3    164.0
# 4      NaN
# 5    132.0
# 6    156.0
# 7    100.0
# 8    141.0
# 9    153.0
# Name: duration, dtype: float64

# %%
dt=df.sort_values('duration')
dt
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 2345  Color        Jane Clark                     NaN       7.0
# 1947  Color               NaN                    12.0       7.0
# 4079  Color               NaN                    38.0      11.0
# 4673  Color       Clark Baker                     1.0      14.0
# 4439  Color  Robert Greenwald                    56.0      20.0
# ...     ...               ...                     ...       ...
# 4517  Color               NaN                     2.0       NaN
# 4609  Color      Wajahat Rauf                     6.0       NaN
# 4690  Color   Joseph Kosinski                     4.0       NaN
# 4948  Color         Valentine                     NaN       NaN
# 4989  Color    Daniel Mellitz                     NaN       NaN
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 2345                     23.0                    51.0     Traci Dinwiddie
# ...

# %%
dt.duration.head(10)
# Out:
# 2345     7.0
# 1947     7.0
# 4079    11.0
# 4673    14.0
# 4439    20.0
# 4803    22.0
# 757     22.0
# 816     22.0
# 833     22.0
# 4281    22.0
# Name: duration, dtype: float64

# %%
da =df.sort_values("duration",ascending =False)
da.duration.head(10)
# Out:
# 1710    511.0
# 2466    334.0
# 1501    330.0
# 1144    325.0
# 3311    300.0
# 2970    293.0
# 1571    289.0
# 2727    286.0
# 883     280.0
# 1980    271.0
# Name: duration, dtype: float64

# %%
df =pd.read_csv("data/flightdata.csv")
df
# Out:
#            FL_DATE OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  \
# 0       2019-01-01                9E               5246    MSP  MKE
# 1       2019-01-01                9E               5249    ATL  PHF
# 2       2019-01-01                9E               5249    PHF  ATL
# 3       2019-01-01                9E               5250    MSP  CLE
# 4       2019-01-01                9E               5254    MSP  RDU
# ...            ...               ...                ...    ...  ...
# 583980  2019-01-31                UA                200    GUM  HNL
# 583981  2019-01-31                UA                174    GUM  SPN
# 583982  2019-01-31                UA                117    SPN  GUM
# 583983  2019-01-31                UA                105    SPN  GUM
# 583984  2019-01-31                UA                104    GUM  SPN
#
#         DEP_DELAY  ARR_DELAY  CANCELLED  ACTUAL_ELAPSED_TIME  CARRIER_DELAY  \
# ...

# %%
df.head()
# Out:
#       FL_DATE OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  DEP_DELAY  \
# 0  2019-01-01                9E               5246    MSP  MKE       33.0
# 1  2019-01-01                9E               5249    ATL  PHF        8.0
# 2  2019-01-01                9E               5249    PHF  ATL       -6.0
# 3  2019-01-01                9E               5250    MSP  CLE       10.0
# 4  2019-01-01                9E               5254    MSP  RDU       -5.0
#
#    ARR_DELAY  CANCELLED  ACTUAL_ELAPSED_TIME  CARRIER_DELAY  WEATHER_DELAY  \
# 0        8.0        0.0                 64.0            NaN            NaN
# 1       -5.0        0.0                 90.0            NaN            NaN
# 2       -2.0        0.0                121.0            NaN            NaN
# 3       -5.0        0.0                102.0            NaN            NaN
# 4      -27.0        0.0                139.0            NaN            NaN
#
#    NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 14
# ...

# %%
df.shape
# Out:
# (583985, 15)

# %%
df.groupby(['ORIGIN'])['DEP_DELAY'].mean()
# Out:
# ORIGIN
# ABE    12.208723
# ABI     5.428571
# ABQ     3.961062
# ABR     9.983333
# ABY     2.783133
#          ...
# VPS     3.480573
# WRG    11.913793
# XNA     9.654492
# YAK    -1.218182
# YUM    -0.756522
# Name: DEP_DELAY, Length: 346, dtype: float64

# %%
df.groupby(['ORIGIN'],sort=False)["DEP_DELAY"].max()
# Out:
# ORIGIN
# MSP    1266.0
# ATL    1434.0
# PHF     193.0
# RIC    1042.0
# OMA    1245.0
#         ...
# SMX     139.0
# OGS     268.0
# PPG      13.0
# OGD      91.0
# LYH      34.0
# Name: DEP_DELAY, Length: 346, dtype: float64

# %%
df.groupby(['ORIGIN'],sort=False)["DEP_DELAY"].mean()
# Out:
# ORIGIN
# MSP    10.043536
# ATL     5.762911
# PHF    -2.709402
# RIC    10.152151
# OMA    10.954499
#          ...
# SMX    17.000000
# OGS    49.900000
# PPG     3.000000
# OGD    35.875000
# LYH    -4.521739
# Name: DEP_DELAY, Length: 346, dtype: float64

# %%
print("Dep_delay from ATL :",round(dt['ATL'],2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ATL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-31a018dfc9e2> in <module>
# ...
