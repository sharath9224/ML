# %%
import pandas as pd

# %%
df=pd.read_csv("data/movie_metadata.csv")
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# Data filtering

# %%
dt=df[df['duration']>170]
dt
# Out:
#                  color     director_name  num_critic_for_reviews  duration  \
# 0                Color     James Cameron                   723.0     178.0
# 10               Color       Zack Snyder                   673.0     183.0
# 17               Color       Joss Whedon                   703.0     173.0
# 23               Color     Peter Jackson                   509.0     186.0
# 25               Color     Peter Jackson                   446.0     201.0
# ...                ...               ...                     ...       ...
# 4113             Color               NaN                    10.0     173.0
# 4238   Black and White     William Wyler                    97.0     172.0
# 4694             Color     Peter Jackson                   446.0     201.0
# 4708             Color  Michael Wadleigh                    53.0     215.0
# 4747   Black and White    Akira Kurosawa                   153.0     202.0
#
# ...

# %%
dt[['director_name','movie_title','duration']]
# Out:
#          director_name                           movie_title  duration
# 0        James Cameron                               Avatar      178.0
# 10         Zack Snyder   Batman v Superman: Dawn of Justice      183.0
# 17         Joss Whedon                         The Avengers      173.0
# 23       Peter Jackson  The Hobbit: The Desolation of Smaug      186.0
# 25       Peter Jackson                            King Kong      201.0
# ...                ...                                   ...       ...
# 4113               NaN                 Creature                  173.0
# 4238     William Wyler          The Best Years of Our Lives      172.0
# 4694     Peter Jackson                            King Kong      201.0
# 4708  Michael Wadleigh                            Woodstock      215.0
# 4747    Akira Kurosawa                        Seven Samurai      202.0
#
# [102 rows x 3 columns]

# %%
df[(df.duration>=160) & (df.num_critic_for_reviews<100) & (df.country =="USA") ]
# Out:
#                  color         director_name  num_critic_for_reviews  \
# 76               Color        Kevin Reynolds                    91.0
# 420              Color          Martin Brest                    98.0
# 499              Color         Kevin Costner                    79.0
# 606              Color         James Cameron                    82.0
# 698              Color       Lawrence Kasdan                    40.0
# 735              Color        Robert Redford                    96.0
# 883              Color           Ron Maxwell                    84.0
# 909              Color        Jonathan Demme                    78.0
# 1124             Color    Billy Bob Thornton                    85.0
# 1125   Black and White          Oliver Stone                    83.0
# 1429             Color             Spike Lee                    61.0
# 1501             Color       Taylor Hackford                    12.0
# 1523             Color         Warren Beatty                    57.0
# ...

# %%
dt=df[(df.duration>=160) & (df.duration<200)]
dt
# Out:
#                  color      director_name  num_critic_for_reviews  duration  \
# 0                Color      James Cameron                   723.0     178.0
# 1                Color     Gore Verbinski                   302.0     169.0
# 3                Color  Christopher Nolan                   813.0     164.0
# 10               Color        Zack Snyder                   673.0     183.0
# 11               Color       Bryan Singer                   434.0     169.0
# ...                ...                ...                     ...       ...
# 4238   Black and White      William Wyler                    97.0     172.0
# 4351             Color               Remo                    15.0     160.0
# 4572   Black and White     Khalid Mohamed                     1.0     167.0
# 4593             Color    Vivek Agnihotri                     4.0     160.0
# 4688             Color        Steve James                    53.0     170.0
#
# ...

# %%
dt=df[df.genres =='Drama']
dt
# Out:
#                  color      director_name  num_critic_for_reviews  duration  \
# 607              Color       Oliver Stone                   297.0     136.0
# 669              Color        Mike Newell                   141.0     117.0
# 683              Color      David Fincher                   315.0     151.0
# 751              Color    Steven Zaillian                   110.0     115.0
# 1147             Color       Gus Van Sant                   137.0     136.0
# ...                ...                ...                     ...       ...
# 5003             Color  Bradley Rust Gray                    61.0      79.0
# 5018             Color      Alex Kendrick                     5.0     120.0
# 5022   Black and White         Jim Chuchu                     6.0      60.0
# 5027             Color       Jafar Panahi                    64.0      90.0
# 5030             Color       Tadeo Garcia                     NaN      84.0
#
# ...

# %%
dt =df[(df.genres =="Action") | (df.genres == "Drama")]
dt
# Out:
#                  color      director_name  num_critic_for_reviews  duration  \
# 217              Color    Joel Schumacher                   183.0     125.0
# 441              Color         Tim Burton                   153.0     126.0
# 607              Color       Oliver Stone                   297.0     136.0
# 669              Color        Mike Newell                   141.0     117.0
# 683              Color      David Fincher                   315.0     151.0
# ...                ...                ...                     ...       ...
# 5003             Color  Bradley Rust Gray                    61.0      79.0
# 5018             Color      Alex Kendrick                     5.0     120.0
# 5022   Black and White         Jim Chuchu                     6.0      60.0
# 5027             Color       Jafar Panahi                    64.0      90.0
# 5030             Color       Tadeo Garcia                     NaN      84.0
#
# ...

# %%
dt[['movie_title']]
# Out:
#                            movie_title
# 217                    Batman & Robin
# 441                    Batman Returns
# 607   Wall Street: Money Never Sleeps
# 669                   Mona Lisa Smile
# 683                        Fight Club
# ...                                ...
# 5003               The Exploding Girl
# 5018                         Flywheel
# 5022             Stories of Our Lives
# 5027                       The Circle
# 5030                   On the Downlow
#
# [247 rows x 1 columns]

# %% [markdown]
# Handling NAN Valves

# %%
df.isnull()
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     False          False                   False     False
# 1     False          False                   False     False
# 2     False          False                   False     False
# 3     False          False                   False     False
# 4      True          False                    True      True
# ...     ...            ...                     ...       ...
# 5038  False          False                   False     False
# 5039  False           True                   False     False
# 5040  False          False                   False     False
# 5041  False          False                   False     False
# 5042  False          False                   False     False
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                       False                   False         False
# 1                       False                   False         False
# ...

# %%
df.notnull()
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0      True           True                    True      True
# 1      True           True                    True      True
# 2      True           True                    True      True
# 3      True           True                    True      True
# 4     False           True                   False     False
# ...     ...            ...                     ...       ...
# 5038   True           True                    True      True
# 5039   True          False                    True      True
# 5040   True           True                    True      True
# 5041   True           True                    True      True
# 5042   True           True                    True      True
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                        True                    True          True
# 1                        True                    True          True
# ...

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
df['country'].head()
print("NAN valves before FillNA :",df["country"].isnull().sum())
# Out:
# NAN valves before FillNA : 0

# %%
print("NAN valves before FillNA :",df["country"].isnull().sum())
#df.country =df.country.fillna("INDIA")

#df['country'].fillna(df['country'].mode()[0],inplace =True)
#df.country =df.country.fillna(df.country.mode()[0])
df['country'].head()
# Out:
# NAN valves before FillNA : 0
# 0    INDIA
# 1    INDIA
# 2    INDIA
# 3    INDIA
# 4    INDIA
# Name: country, dtype: object

# %%
df['country'].fillna(df['country'].mode()[0],inplace =True)

# %%
df['duration'].head()
# Out:
# 0    178.0
# 1    169.0
# 2    148.0
# 3    164.0
# 4      NaN
# Name: duration, dtype: float64

# %% [markdown]
# fill na using numericak values

# %%
df['duration'].head()
print("nan values  fill ns using :",df["duration"].isnull().sum())
# Out:
# nan values  fill ns using : 15

# %%
df.duration=df.duration.fillna(round(df.duration.mean(),1))
df["duration"].head()
# Out:
# 0    178.0
# 1    169.0
# 2    148.0
# 3    164.0
# 4    107.2
# Name: duration, dtype: float64
